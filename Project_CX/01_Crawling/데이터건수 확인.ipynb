# %%
from tqdm import tqdm
import time
import re
import pandas as pd

# %%
# 확인
import os

Dir = './results/'
fileEx = '.xlsx'

xlsx_list = [file for file in os.listdir(Dir) if file.endswith(fileEx)]

total_n = 0
for xl in xlsx_list:
    df = pd.read_excel(Dir+xl)
    total_n += len(df)
    print(f'{xl}: {len(df)}')
    
print("총: ", total_n)

# xlsx_list0 = xlsx_list[4]
# print(xlsx_list0)
# df = pd.read_excel(Dir+xlsx_list0)
# df


# 냉장고 4,015
# 식기세척기 3,546
# 인덕션 1,039
# 광파오븐 883
# 정수기 352
# Out:
# 네이버_블로그_냉장고 정리.xlsx: 776
# 네이버_블로그_요리 설거지.xlsx: 926
# 네이버_블로그_주방 스트레스.xlsx: 869
# 네이버_블로그_유통기한 관리.xlsx: 908
# 네이버_블로그_음식물쓰레기 처리.xlsx: 834
# 네이버_블로그_식사 준비 시간.xlsx: 925
# 네이버_블로그_기름때 청소.xlsx: 808
# 네이버_블로그_설거지 불편.xlsx: 1012
# 총:  7058
